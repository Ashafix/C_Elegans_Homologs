# %%
import pandas as pd
import os

# %%
import skimage

# %%
img = skimage.io.imread('c:/users/ashafix/Downloads/Cardinal_0007_3025810472.jpg')

# %%
filename = 'BIOGRID-ORGANISM-Caenorhabditis_elegans-3.5.173.tab.txt'
with open(filename) as f:
    for i in range(50):
        print(i, f.readline())
# Out:
# 0 IN NO EVENT SHALL MOUNT SINAI HOSPITAL BE LIABLE TO ANY PARTY FOR DIRECT, INDIRECT, SPECIAL, INCIDENTAL, OR CONSEQUENTIAL
#
# 1 DAMAGES, INCLUDING LOST PROFITS, ARISING OUT OF THE USE OF THIS SOFTWARE AND ITS DOCUMENTATION, EVEN IF MOUNT SINAI HOSPITAL
#
# 2 HAS BEEN ADVISED OF THE POSSIBILITY OF SUCH DAMAGE.
#
# 3
#
# 4 MOUNT SINAI HOSPITAL SPECIFICALLY DISCLAIMS ANY IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR A PARTICULAR PURPOSE.
#
# 5 THE SOFTWARE AND ACCOMPANYING DOCUMENTATION, IF ANY, PROVIDED HEREUNDER IS PROVIDED "AS IS". MOUNT SINAI HOSPITAL HAS NO
#
# 6 OBLIGATION TO PROVIDE MAINTENANCE, SUPPORT, UPDATES, ENHANCEMENTS, OR MODIFICATIONS.
#
# 7
#
# 8 Published research assisted by this document should cite the original publishing author, as well as:
#
# 9 In any articles making use of this data, please refer to:
#
# 10 Stark C, Breitkreutz BJ, Reguly T, Boucher L, Breitkreutz A, Tyers M. BioGRID: A General Repository for Interaction Datasets.
#
# ...

# %%
df_interact= pd.read_csv(filename, sep='\t', skiprows=34)

# %%
symbols = ['clec-41', 'unc-46', 'gpx-3', 'dod-21', 'try-3', 'clec-198', 'clx-1', 'clec-1', 'cyp-33C5', 'tag-196', 'irld-34', 'ora-1', 'gpn-1', 'dsl-6', 'irld-44', 'ins-22', 'scl-25','lys-2', 'lys-3', 'clec-163' ,'nlp-17', 'lron-13']

# %%
df_interact
# Out:
#         INTERACTOR_A    INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 0         CELE_AC7.2    CELE_W07G4.5             soc-2           W07G4.5
# 1         CELE_AC7.2         ZK792.6             soc-2            let-60
# 2           B0024.12         B0365.1             gna-1            acly-2
# 3           B0024.12    CELE_C25F6.2             gna-1             dlg-1
# 4           B0024.12    CELE_C38D4.6             gna-1             pal-1
# 5           B0024.12    CELE_W02G9.3             gna-1           W02G9.3
# 6      CELE_B0024.14   CELE_B0024.14             crm-1             crm-1
# 7      CELE_B0024.14    CELE_B0507.1             crm-1           B0507.1
# 8      CELE_B0024.14         C02C2.1             crm-1             tyr-1
# 9      CELE_B0024.14         C34G6.2             crm-1             tyr-4
# 10     CELE_B0024.14    CELE_C37C3.6             crm-1             mig-6
# 11     CELE_B0024.14    CELE_C54D2.2             crm-1           C54D2.2
# ...

# %%
for symbol in symbols:
    print(symbol, len(df_interact[df_interact.OFFICIAL_SYMBOL_A == symbol]))
# Out:
# clec-41 0
# unc-46 0
# gpx-3 0
# dod-21 0
# try-3 0
# clec-198 0
# clx-1 0
# clec-1 0
# cyp-33C5 0
# tag-196 0
# irld-34 0
# ora-1 0
# gpn-1 0
# dsl-6 0
# irld-44 0
# ins-22 0
# scl-25 0
# lys-2 0
# lys-3 0
# clec-163 0
# nlp-17 0
# lron-13 0

# %%
for symbol in symbols:
    print(symbol, len(df_interact[df_interact.OFFICIAL_SYMBOL_A.str.contains(symbol) ]))
# Out:
# clec-41 0
# unc-46 0
# gpx-3 0
# dod-21 0
# try-3 0
# clec-198 0
# clx-1 0
# clec-1 0
# cyp-33C5 0
# tag-196 0
# irld-34 0
# ora-1 0
# gpn-1 0
# dsl-6 0
# irld-44 0
# ins-22 0
# scl-25 0
# lys-2 0
# lys-3 0
# clec-163 0
# nlp-17 0
# lron-13 0

# %%
ids = ['B0365.6', 'C04F5.3', 'C06A6.5', 'C11E4.2', 'C13C12.2', 'C16C8.9', 'C16D9.8', 'C17H12.8', 'C32H11.10', 'C36C5.5', 'C43G2.5', 'C47E12.9', 'C49C3.11', 'C49C3.13', 'C50F7.2', 'F01G10.6', 'F01G10.9', 'F11E6.3', 'F14F9.5', 'F16B4.7', 'F22B7.1', 'F25B4.9', 'F26E4.3', 'F37C12.10', 'F38B2.2', 'F41B5.3', 'F41E6.6', 'F46B3.9', 'F48C1.8', 'F53H4.2', 'F54E2.1', 'F54G8.1', 'F56B6.6', 'F57F4.4', 'F57H12.3', 'F59D12.4', 'H02I12.4', 'K02A11.3', 'K04F1.11', 'M04D8.2']

# %%
for symbol in ids:
    hits = len(df_interact[df_interact.OFFICIAL_SYMBOL_A.str.contains(symbol) ])
    if hits > 0:
        print(symbol, hits)    
for symbol in ids:
    hits = len(df_interact[df_interact.OFFICIAL_SYMBOL_A == symbol])
    if hits > 0:
        print(symbol, hits)

# %%
df_interact[df_interact.ALIASES_FOR_A.str.contains('F11E6.3'.lower())]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-cf5d98034dcd> in <module>
# ----> 1 df_interact[df_interact.ALIASES_FOR_A.str.lower.contains('F11E6.3'.lower())]
#
# AttributeError: 'function' object has no attribute 'contains'

# %%
df_interact.OFFICIAL_SYMBOL_A
# Out:
# 0          soc-2
# 1          soc-2
# 2          gna-1
# 3          gna-1
# 4          gna-1
# 5          gna-1
# 6          crm-1
# 7          crm-1
# 8          crm-1
# 9          crm-1
# 10         crm-1
# 11         crm-1
# 12         crm-1
# 13         crm-1
# 14         crm-1
# 15         crm-1
# 16         crm-1
# 17         crm-1
# 18         crm-1
# 19         crm-1
# 20         crm-1
# 21         crm-1
# 22         crm-1
# 23         crm-1
# 24         crm-1
# 25         crm-1
# 26         crm-1
# 27         crm-1
# 28         crm-1
# 29         crm-1
#           ...
# 8668     M01A8.2
# 8669       rer-1
# 8670       ehs-1
# 8671       fem-1
# 8672      unc-84
# 8673      unc-84
# 8674      unc-84
# 8675      unc-84
# 8676        PAK1
# 8677       ced-2
# 8678       ced-2
# 8679       ced-2
# 8680       ced-2
# 8681       ced-5
# 8682       ced-2
# 8683       soc-1
# 8684       chn-1
# 8685       chn-1
# 8686      vps-51
# 8687      vps-52
# 8688       ubq-1
# ...

# %%
df_interact
# Out:
#         INTERACTOR_A    INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 0         CELE_AC7.2    CELE_W07G4.5             soc-2           W07G4.5
# 1         CELE_AC7.2         ZK792.6             soc-2            let-60
# 2           B0024.12         B0365.1             gna-1            acly-2
# 3           B0024.12    CELE_C25F6.2             gna-1             dlg-1
# 4           B0024.12    CELE_C38D4.6             gna-1             pal-1
# 5           B0024.12    CELE_W02G9.3             gna-1           W02G9.3
# 6      CELE_B0024.14   CELE_B0024.14             crm-1             crm-1
# 7      CELE_B0024.14    CELE_B0507.1             crm-1           B0507.1
# 8      CELE_B0024.14         C02C2.1             crm-1             tyr-1
# 9      CELE_B0024.14         C34G6.2             crm-1             tyr-4
# 10     CELE_B0024.14    CELE_C37C3.6             crm-1             mig-6
# 11     CELE_B0024.14    CELE_C54D2.2             crm-1           C54D2.2
# ...
