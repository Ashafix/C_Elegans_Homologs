# %%
import sys
import os
import collections
from scipy import stats

# %%
folder = 'Z:\celegans\secretome'

# %%
with open('top51.fasta') as f:
    top57 = f.readlines()
top57 = [t for t in top57 if t.startswith('>')]
top57 = [t.split('|')[1] for t in top57 if t.startswith('>')]

# %%
len(top57)
# Out:
# 57

# %%
files = [f for f in os.listdir(folder) if f.endswith('.fa')]

# %%
len(files)
# Out:
# 3672

# %%
aa = set()

# %%
def count_aa(file, top57='', ignore_length=-1):
    with open(file, 'r') as f:
        lines = f.readlines()
    file = file.split('.')[0].rsplit('\\')[-1]
    if file in top57:
        return
        #top57.pop(top57.index(file))
    counts = collections.defaultdict(int)
    counter = 0
    for line in lines:
        if line.startswith('>'):
            continue
        for x in line.strip():
            counter += 1
            if counter < ignore_length:
                continue
            counts[x] += 1
            aa.add(x)
    s = sum(counts.values())
    for k, v in counts.items():
        counts[k] = v /s
    return counts

# %%
counts = {}

for file in files:
    c = count_aa(os.path.join(folder, file), top57=top57)
    if c is not None:
        counts[file.split('.')[0]] = c

# %%
all_proteins = [f for f in os.listdir(os.path.abspath(os.path.join(folder, '..'))) if f.endswith('fa')]

# %%
counts_all = {}

for file in all_proteins:
    c = count_aa(os.path.join('z:\\celegans', file), top57=top57)
    if c is not None:
        counts_all[file.split('.')[0]] = c

# %%
len(counts)
# Out:
# 3615

# %%
counts_top = {}

for file in top57:
    c = count_aa(os.path.join(folder, file + '.fa'), top57=[])
    if c is not None:
        counts_top[file] = c

# %%
len(files)
# Out:
# 3672

# %%
for a in aa:
    prob1 = []
    prob2 = []
    for prob in counts.values():
        prob1.append(prob[a])
    for prob in counts_top.values():
        prob2.append(prob[a])
    ttest = stats.ttest_ind(prob1, prob2)
    if ttest[1] < 0.05:
        print(a, ttest[1])
        print(sum(prob1)/len(prob1) * 100, sum(prob2)/len(prob2) * 100)
# Out:
# N 0.022319619428223518
# 5.1609674790179065 5.860823181368706

# %%
len(counts)
# Out:
# 3615

# %%
sum(prob1)/len(prob1), sum(prob2)/len(prob2)
# Out:
# (0.03613876118319215, 0.0385762822089534)

# %%
for a in aa:
    prob1 = []
    prob2 = []
    for prob in counts.values():
        prob1.append(prob[a])
    for prob in counts_all.values():
        prob2.append(prob[a])
    ttest = stats.ttest_ind(prob1, prob2)
    if ttest[1] < 0.05:
        print(a, ttest)
        print(sum(prob1)/len(prob1), sum(prob2)/len(prob2))
# Out:
# V Ttest_indResult(statistic=-4.61249925971557, pvalue=3.994288404368956e-06)
# 0.06018687518794115 0.06184569611567519
# W Ttest_indResult(statistic=2.5572666489982363, pvalue=0.010554500309739954)
# 0.011596430896333762 0.011177800231394513
# H Ttest_indResult(statistic=-12.77156676533676, pvalue=2.928208237269525e-37)
# 0.019720967836068505 0.02297354521137021
# S Ttest_indResult(statistic=-6.393134458889781, pvalue=1.6480555415656495e-10)
# 0.07687435725086472 0.08012224585308904
# R Ttest_indResult(statistic=-18.071306236441057, pvalue=1.2556070649816506e-72)
# 0.04445840514490193 0.05213798868721801
# T Ttest_indResult(statistic=10.930310889157514, pvalue=9.267894598423227e-28)
# 0.06304535868549616 0.05818017467723801
# K Ttest_indResult(statistic=-6.7987820099063505, pvalue=1.0739901957946162e-11)
# 0.05950816800736238 0.063163407839982
# I Ttest_indResult(statistic=-12.362692867322785, pvalue=5.021739694596554e-35)
# 0.05637527933013214 0.06177986939882165
# A Ttest_indResult(statistic=4.6571441978732055, pvalue=3.219412169336967e-06)
# 0.06589616479995568 0.0636389272972405
# M Ttest_indResult(statistic=-12.82590977307283, pvalue=1.45982190532183e-37)
# 0.025192719321192054 0.028434102913362035
# G Ttest_indResult(statistic=20.002695517808974, pvalue=1.8644772126093217e-88)
# 0.06806909135451036 0.05491838153807347
# E Ttest_indResult(statistic=-15.243709620620338, pvalue=2.7940543830264705e-52)
# 0.054881249687579986 0.0627646255462319
# N Ttest_indResult(statistic=9.499130703638304, pvalue=2.2615907363134705e-21)
# 0.05160967479017906 0.04835271657995527
# Q Ttest_indResult(statistic=-2.0401112711233744, pvalue=0.04134761618132008)
# 0.03995793753568707 0.04081157261461361
# L Ttest_indResult(statistic=-13.617090892244374, pvalue=4.178273912893316e-42)
# 0.0789808631018571 0.08577713014023228
# C Ttest_indResult(statistic=28.13365337959343, pvalue=5.261452145358731e-172)
# 0.032820412807033204 0.021948397768275896
# P Ttest_indResult(statistic=9.975793731684824, pvalue=2.1084208531386538e-23)
# 0.05397362097293895 0.04900934030130166
# Y Ttest_indResult(statistic=10.864349285200255, pvalue=1.90788119086154e-27)
# 0.03613876118319215 0.03248305973584756

# %%
import pandas as pd
import pickle
import numpy as np
import scipy.spatial
import sklearn.cluster

# %%
with open(os.path.abspath(os.path.join(os.getcwd(), r'../secondary-structure-parser', 'df_all.pickle')), 'rb') as f:
    df = pickle.load(f)

# %%
points = []
for t in sorted(top57):
    x = sum(df.loc[t]['probabilities_0']) / len(df.loc[t])
    y = sum(df.loc[t]['probabilities_1']) / len(df.loc[t])
    z = sum(df.loc[t]['disordered']) / len(df.loc[t])
    points.append([x, y, z])

# %%
points = np.array(points)
dist_matrix = scipy.spatial.distance_matrix(points, points)

clusters = sklearn.cluster.KMeans(random_state=42).fit_predict(dist_matrix)

# %%
composition_cluster = {}
proteins_in_cluster = {}
names = sorted(top57)
for i in range(max(clusters) + 1):
    composition_cluster[i] = {}
    proteins_in_cluster[i] = []
    for ix, cluster in enumerate(clusters):
        if cluster == i:
            proteins_in_cluster[i].append(names[ix])
    for protein in proteins_in_cluster[i]:
        c = count_aa(os.path.join(folder, protein + '.fa'))
        composition_cluster[i][protein] = c

# %%
for i in composition_cluster:
    for a in aa:
        prob1 = []
        prob2 = []
        for prob in counts.values():
            prob1.append(prob[a])
        for prob in composition_cluster[i].values():
            prob2.append(prob[a])
        ttest = stats.ttest_ind(prob1, prob2)
        if ttest[1] < 0.01:
            print('AA: {}, Cluster: {}, p-value: {:.6f}'.format(a, i, ttest[1]))
            print(sum(prob1)/len(prob1), sum(prob2)/len(prob2))
# Out:
# AA: N, Cluster: 0, p-value: 0.005621
# 0.05160967479017906 0.07563428684499778
# AA: W, Cluster: 1, p-value: 0.000707
# 0.011596430896333762 0.020149641741204417
# AA: H, Cluster: 4, p-value: 0.003116
# 0.019720967836068505 0.04106608060933408
# AA: I, Cluster: 4, p-value: 0.001688
# 0.05637527933013214 0.020417078682329545
# AA: G, Cluster: 4, p-value: 0.000000
# 0.06806909135451036 0.22006571306030426
# AA: L, Cluster: 4, p-value: 0.003225
# 0.0789808631018571 0.0382549450536469
# AA: P, Cluster: 4, p-value: 0.000001
# 0.05397362097293895 0.13763043740478836
# C:\Users\ashafix\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\ashafix\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\ashafix\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Users\ashafix\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\ashafix\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
proteins_in_cluster[7]
# Out:
# ['O46001', 'O61952', 'O62455', 'P91047', 'Q22903']

# %%
sum(df.loc[t]['disordered']) / len(df.loc[t])
# Out:
# 0.12956810631229235

# %%
df.loc[t]
# Out:
#     prediction  probabilities_0  probabilities_1  probabilities_2  disordered  \
# 1            C            0.003            0.000            0.996        True
# 2            H            0.808            0.001            0.191        True
# 3            H            0.970            0.001            0.030        True
# 4            H            0.982            0.000            0.018        True
# 5            H            0.992            0.000            0.008        True
# 6            H            0.997            0.000            0.003        True
# 7            H            0.996            0.000            0.004        True
# 8            H            0.994            0.000            0.006        True
# 9            H            0.992            0.000            0.008        True
# 10           H            0.993            0.000            0.007        True
# 11           H            0.985            0.000            0.015        True
# 12           H            0.963            0.001            0.036        True
# 13           H            0.903            0.002            0.095        True
# 14           H            0.716            0.003            0.280        True
# 15           C            0.410            0.009            0.581        True
# 16           C            0.007            0.008            0.985        True
# 17           C            0.002            0.023            0.975        True
# 18           C            0.003            0.056            0.942        True
# 19           C            0.002            0.042            0.956        True
# 20           C            0.011            0.039            0.950        True
# 21           C            0.011            0.039            0.950        True
# 22           C            0.012            0.028            0.960        True
# 23           C            0.003            0.011            0.986        True
# 24           C            0.003            0.015            0.982        True
# 25           C            0.002            0.019            0.979       False
# 26           C            0.002            0.037            0.960       False
# 27           C            0.010            0.059            0.931       False
# 28           C            0.044            0.125            0.831       False
# 29           C            0.052            0.222            0.726       False
# 30           C            0.057            0.270            0.673       False
# ..         ...              ...              ...              ...         ...
# 272          H            0.610            0.006            0.384       False
# 273          H            0.620            0.007            0.373       False
# 274          H            0.664            0.010            0.326       False
# 275          H            0.627            0.011            0.362       False
# 276          H            0.583            0.020            0.397        True
# 277          H            0.524            0.044            0.432        True
# 278          C            0.277            0.064            0.658        True
# 279          C            0.053            0.048            0.899        True
# 280          C            0.016            0.017            0.967        True
# 281          C            0.011            0.007            0.983        True
# 282          C            0.011            0.007            0.983        True
# 283          C            0.005            0.004            0.991        True
# 284          C            0.003            0.004            0.992        True
# 285          C            0.002            0.003            0.995        True
# 286          C            0.001            0.002            0.997        True
# 287          C            0.001            0.002            0.997        True
# 288          C            0.003            0.003            0.993        True
# 289          C            0.005            0.005            0.989        True
# 290          C            0.004            0.010            0.985        True
# 291          C            0.002            0.016            0.981       False
# 292          C            0.001            0.046            0.953       False
# 293          C            0.002            0.333            0.666       False
# 294          E            0.001            0.825            0.174       False
# 295          E            0.001            0.956            0.043       False
# 296          E            0.002            0.942            0.056       False
# 297          C            0.001            0.251            0.748       False
# 298          C            0.003            0.185            0.812       False
# 299          C            0.004            0.163            0.833       False
# 300          C            0.002            0.075            0.923       False
# 301          C            0.000            0.001            0.999       False
#
#      probability
# 1           0.93
# 2           0.94
# 3           0.95
# 4           0.96
# 5           0.95
# 6           0.96
# 7           0.96
# 8           0.98
# 9           0.98
# 10          0.98
# 11          0.98
# 12          0.97
# 13          0.97
# 14          0.97
# 15          0.94
# 16          0.92
# 17          0.90
# 18          0.84
# 19          0.83
# 20          0.74
# 21          0.69
# 22          0.58
# 23          0.50
# 24          0.51
# 25          0.43
# 26          0.39
# 27          0.32
# 28          0.33
# 29          0.28
# 30          0.25
# ..           ...
# 272         0.25
# 273         0.21
# 274         0.29
# 275         0.49
# 276         0.63
# 277         0.71
# 278         0.75
# 279         0.75
# 280         0.70
# 281         0.77
# 282         0.88
# 283         0.89
# 284         0.88
# 285         0.83
# 286         0.79
# 287         0.79
# 288         0.74
# 289         0.67
# 290         0.66
# 291         0.49
# 292         0.37
# 293         0.36
# 294         0.39
# 295         0.44
# 296         0.40
# 297         0.35
# 298         0.31
# 299         0.24
# 300         0.27
# 301         0.34
#
# [301 rows x 6 columns]
